# %% [markdown]
# # POSPage.tsx Syntax Debug
# Load the source file and inspect the lines around the reported build error at line 690.

# %%
from pathlib import Path
path = Path('src/pages/POSPage.tsx')
text = path.read_text(encoding='utf-8')
lines = text.splitlines()
for i in range(650, 691):
    print(f"{i+1}: {lines[i]}")

print('\n---')
print('Total lines:', len(lines))
